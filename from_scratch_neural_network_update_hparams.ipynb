# %% [markdown]
# # Copy of From Scratch Neural Networks
# the difference in here is that the I have written seperate functions for each gradient

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
import os
import kagglehub
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# %%
warnings.filterwarnings('ignore')

# %%
path = kagglehub.dataset_download("fedesoriano/cirrhosis-prediction-dataset")

path
# Out:
# '/home/yashkathe/.cache/kagglehub/datasets/fedesoriano/cirrhosis-prediction-dataset/versions/2'

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### Read the Data

# %%
df = pd.read_csv(f'{path}/{os.listdir(path)[0]}')

df.describe()
# Out:
#                ID       N_Days           Age   Bilirubin  Cholesterol  \
# count  418.000000   418.000000    418.000000  418.000000   284.000000
# mean   209.500000  1917.782297  18533.351675    3.220813   369.510563
# std    120.810458  1104.672992   3815.845055    4.407506   231.944545
# min      1.000000    41.000000   9598.000000    0.300000   120.000000
# 25%    105.250000  1092.750000  15644.500000    0.800000   249.500000
# 50%    209.500000  1730.000000  18628.000000    1.400000   309.500000
# 75%    313.750000  2613.500000  21272.500000    3.400000   400.000000
# max    418.000000  4795.000000  28650.000000   28.000000  1775.000000
#
#           Albumin      Copper      Alk_Phos        SGOT  Tryglicerides  \
# count  418.000000  310.000000    312.000000  312.000000     282.000000
# mean     3.497440   97.648387   1982.655769  122.556346     124.702128
# std      0.424972   85.613920   2140.388824   56.699525      65.148639
# min      1.960000    4.000000    289.000000   26.350000      33.000000
# 25%      3.242500   41.250000    871.500000   80.600000      84.250000
# 50%      3.530000   73.000000   1259.000000  114.700000     108.000000
# 75%      3.770000  123.000000   1980.000000  151.900000     151.000000
# max      4.640000  588.000000  13862.400000  457.250000     598.000000
#
#         Platelets  Prothrombin       Stage
# count  407.000000   416.000000  412.000000
# mean   257.024570    10.731731    3.024272
# std     98.325585     1.022000    0.882042
# min     62.000000     9.000000    1.000000
# 25%    188.500000    10.000000    2.000000
# 50%    251.000000    10.600000    3.000000
# 75%    318.000000    11.100000    4.000000
# max    721.000000    18.000000    4.000000

# %%
def missing_values(df):
    missing_values = df.iloc[:, 1:].isnull()
    return missing_values.sum()

# %%
missing_values(df)
# Out:
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %% [markdown]
# ### Drop Missing Value with more than Threshold

# %%
# let threshold = 80% of data

threshold = 0.80 * len(df)

df = df.dropna(thresh=threshold, axis=1)

# %%
# also drop columns with stage missing
df = df.dropna(subset=['Stage'])

# %%
df = df.drop('ID', axis=1)

# %%
missing_values(df)
# Out:
# Status          0
# Age             0
# Sex             0
# Edema           0
# Bilirubin       0
# Albumin         0
# Platelets      11
# Prothrombin     2
# Stage           0
# dtype: int64

# %%
df.describe()
# Out:
#             N_Days           Age   Bilirubin     Albumin   Platelets  \
# count   412.000000    412.000000  412.000000  412.000000  401.000000
# mean   1916.837379  18498.286408    3.227670    3.500073  256.102244
# std    1099.941147   3823.705746    4.429421    0.423948   95.750598
# min      41.000000   9598.000000    0.300000    1.960000   62.000000
# 25%    1094.250000  15609.250000    0.800000    3.247500  189.000000
# 50%    1713.500000  18628.000000    1.400000    3.530000  249.000000
# 75%    2610.500000  21200.500000    3.400000    3.782500  318.000000
# max    4795.000000  28650.000000   28.000000    4.640000  563.000000
#
#        Prothrombin       Stage
# count   410.000000  412.000000
# mean     10.733415    3.024272
# std       1.026557    0.882042
# min       9.000000    1.000000
# 25%      10.000000    2.000000
# 50%      10.600000    3.000000
# 75%      11.100000    4.000000
# max      18.000000    4.000000

# %% [markdown]
# ### Replace rest of the missing values

# %%
# the std deviation is low and hence can take mean

df['Prothrombin'] = df['Prothrombin'].fillna(df['Prothrombin'].mean())
df['Platelets'] = df['Platelets'].fillna(df['Platelets'].mean)

missing_values(df)
# Out:
# Status         0
# Age            0
# Sex            0
# Edema          0
# Bilirubin      0
# Albumin        0
# Platelets      0
# Prothrombin    0
# Stage          0
# dtype: int64

# %% [markdown]
# ### Make data numerical

# %%
df
# Out:
#      N_Days Status    Age Sex Edema  Bilirubin  Albumin Platelets  \
# 0       400      D  21464   F     Y       14.5     2.60     190.0
# 1      4500      C  20617   F     N        1.1     4.14     221.0
# 2      1012      D  25594   M     S        1.4     3.48     151.0
# 3      1925      D  19994   F     S        1.8     2.54     183.0
# 4      1504     CL  13918   F     N        3.4     3.53     136.0
# ..      ...    ...    ...  ..   ...        ...      ...       ...
# 413     681      D  24472   F     N        1.2     2.96     174.0
# 414    1103      C  14245   F     N        0.9     3.83     180.0
# 415    1055      C  20819   F     N        1.6     3.42     143.0
# 416     691      C  21185   F     N        0.8     3.75     269.0
# 417     976      C  19358   F     N        0.7     3.29     350.0
#
#      Prothrombin  Stage
# 0           12.2    4.0
# 1           10.6    3.0
# 2           12.0    4.0
# 3           10.3    4.0
# 4           10.9    3.0
# ..           ...    ...
# 413         10.9    3.0
# 414         11.2    4.0
# 415          9.9    3.0
# 416         10.4    3.0
# 417         10.6    4.0
#
# [412 rows x 10 columns]

# %%
df['Status'].unique(), df['Sex'].unique(), df['Edema'].unique()
# Out:
# (array(['D', 'C', 'CL'], dtype=object),
#  array(['F', 'M'], dtype=object),
#  array(['Y', 'N', 'S'], dtype=object))

# %%
df['Status'] = df['Status'].map({'D': 0, 'C': 1, 'CL': 2})
df['Sex'] = df['Sex'].map({'F': 0, 'M': 1})
df['Edema'] = df['Edema'].map({'Y':0, 'N': 1, 'S': 0})

df.describe()
# Out:
#             N_Days      Status           Age         Sex       Edema  \
# count   412.000000  412.000000    412.000000  412.000000  412.000000
# mean   1916.837379    0.679612  18498.286408    0.106796    0.844660
# std    1099.941147    0.583030   3823.705746    0.309229    0.362669
# min      41.000000    0.000000   9598.000000    0.000000    0.000000
# 25%    1094.250000    0.000000  15609.250000    0.000000    1.000000
# 50%    1713.500000    1.000000  18628.000000    0.000000    1.000000
# 75%    2610.500000    1.000000  21200.500000    0.000000    1.000000
# max    4795.000000    2.000000  28650.000000    1.000000    1.000000
#
#         Bilirubin     Albumin  Prothrombin       Stage
# count  412.000000  412.000000   412.000000  412.000000
# mean     3.227670    3.500073    10.733415    3.024272
# std      4.429421    0.423948     1.024056    0.882042
# min      0.300000    1.960000     9.000000    1.000000
# 25%      0.800000    3.247500    10.000000    2.000000
# 50%      1.400000    3.530000    10.600000    3.000000
# 75%      3.400000    3.782500    11.100000    4.000000
# max     28.000000    4.640000    18.000000    4.000000

# %%
df.dtypes
# Out:
# N_Days           int64
# Status           int64
# Age              int64
# Sex              int64
# Edema            int64
# Bilirubin      float64
# Albumin        float64
# Platelets       object
# Prothrombin    float64
# Stage          float64
# dtype: object

# %%
df['Platelets'] = pd.to_numeric(df['Platelets'], errors='coerce')

# %%
missing_values(df)
# Out:
# Status          0
# Age             0
# Sex             0
# Edema           0
# Bilirubin       0
# Albumin         0
# Platelets      11
# Prothrombin     0
# Stage           0
# dtype: int64

# %%
df['Platelets'] = df['Platelets'].fillna(df['Platelets'].median())

# %%
df.columns
# Out:
# Index(['N_Days', 'Status', 'Age', 'Sex', 'Edema', 'Bilirubin', 'Albumin',
#        'Platelets', 'Prothrombin', 'Stage'],
#       dtype='object')

# %%
df.dtypes
# Out:
# N_Days           int64
# Status           int64
# Age              int64
# Sex              int64
# Edema            int64
# Bilirubin      float64
# Albumin        float64
# Platelets      float64
# Prothrombin    float64
# Stage          float64
# dtype: object

# %%
def plot_boxplots_in_subplots(df, cols_per_row=2, figsize=(10, 5)):
    
    n_cols = len(df.columns)
    n_rows = int(np.ceil(n_cols / cols_per_row)) 
    
    # Create subplots: n_rows rows, cols_per_row columns
    fig, axes = plt.subplots(n_rows, cols_per_row, figsize=figsize)
    
    # Flatten the axes array
    axes = axes.flatten()
    
    # Loop through the columns and plot each one in a separate subplot
    for i, cname in enumerate(df.columns):
        sns.boxplot(x=df[cname], ax=axes[i])  # Plot in the ith subplot
        axes[i].set_title(f'Box plot for {cname}')
    
    # Adjust layout to prevent overlap
    plt.tight_layout()
    plt.show()

# %%
df.describe()
# Out:
#             N_Days      Status           Age         Sex       Edema  \
# count   412.000000  412.000000    412.000000  412.000000  412.000000
# mean   1916.837379    0.679612  18498.286408    0.106796    0.844660
# std    1099.941147    0.583030   3823.705746    0.309229    0.362669
# min      41.000000    0.000000   9598.000000    0.000000    0.000000
# 25%    1094.250000    0.000000  15609.250000    0.000000    1.000000
# 50%    1713.500000    1.000000  18628.000000    0.000000    1.000000
# 75%    2610.500000    1.000000  21200.500000    0.000000    1.000000
# max    4795.000000    2.000000  28650.000000    1.000000    1.000000
#
#         Bilirubin     Albumin   Platelets  Prothrombin       Stage
# count  412.000000  412.000000  412.000000   412.000000  412.000000
# mean     3.227670    3.500073  255.912621    10.733415    3.024272
# std      4.429421    0.423948   94.467529     1.024056    0.882042
# min      0.300000    1.960000   62.000000     9.000000    1.000000
# 25%      0.800000    3.247500  190.000000    10.000000    2.000000
# 50%      1.400000    3.530000  249.000000    10.600000    3.000000
# 75%      3.400000    3.782500  314.500000    11.100000    4.000000
# max     28.000000    4.640000  563.000000    18.000000    4.000000

# %%
plot_boxplots_in_subplots(df)

# %%
df.describe()
# Out:
#             N_Days      Status           Age         Sex       Edema  \
# count   412.000000  412.000000    412.000000  412.000000  412.000000
# mean   1916.837379    0.679612  18498.286408    0.106796    0.844660
# std    1099.941147    0.583030   3823.705746    0.309229    0.362669
# min      41.000000    0.000000   9598.000000    0.000000    0.000000
# 25%    1094.250000    0.000000  15609.250000    0.000000    1.000000
# 50%    1713.500000    1.000000  18628.000000    0.000000    1.000000
# 75%    2610.500000    1.000000  21200.500000    0.000000    1.000000
# max    4795.000000    2.000000  28650.000000    1.000000    1.000000
#
#         Bilirubin     Albumin   Platelets  Prothrombin       Stage
# count  412.000000  412.000000  412.000000   412.000000  412.000000
# mean     3.227670    3.500073  255.912621    10.733415    3.024272
# std      4.429421    0.423948   94.467529     1.024056    0.882042
# min      0.300000    1.960000   62.000000     9.000000    1.000000
# 25%      0.800000    3.247500  190.000000    10.000000    2.000000
# 50%      1.400000    3.530000  249.000000    10.600000    3.000000
# 75%      3.400000    3.782500  314.500000    11.100000    4.000000
# max     28.000000    4.640000  563.000000    18.000000    4.000000

# %% [markdown]
# ### Handle Outliers

# %%
def handle_outliers(df, iqr_multiplier=1.5):

    for col in df.select_dtypes(include=[np.number]).columns:  # Only process numeric columns
        
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - iqr_multiplier * IQR
        upper_bound = Q3 + iqr_multiplier * IQR


        df[col] = np.where(df[col] < lower_bound, lower_bound, df[col])
        df[col] = np.where(df[col] > upper_bound, upper_bound, df[col])
    
    return df

# %%
df = handle_outliers(df)

# %%
plot_boxplots_in_subplots(df)

# %%
def plot_distributions_in_subplots(df, cols_per_row=2, figsize=(20, 10), kde=True):

    n_cols = len(df.columns)
    n_rows = int(np.ceil(n_cols / cols_per_row))  # Calculate number of rows

    fig, axes = plt.subplots(n_rows, cols_per_row, figsize=figsize)

    # Flatten the axes array for easy iteration
    axes = axes.flatten()

    # Loop through the columns and plot each one in a separate subplot
    for i, cname in enumerate(df.columns):
        sns.histplot(df[cname], kde=kde, ax=axes[i], color='blue', bins=20)  # Histogram with KDE
        axes[i].set_title(f'Distribution of {cname}')

    # Remove empty subplots if any
    for j in range(n_cols, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# %%
plot_distributions_in_subplots(df)

# %%
df.describe()
# Out:
#             N_Days      Status           Age    Sex  Edema   Bilirubin  \
# count   412.000000  412.000000    412.000000  412.0  412.0  412.000000
# mean   1916.837379    0.679612  18498.286408    0.0    1.0    2.488592
# std    1099.941147    0.583030   3823.705746    0.0    0.0    2.294273
# min      41.000000    0.000000   9598.000000    0.0    1.0    0.300000
# 25%    1094.250000    0.000000  15609.250000    0.0    1.0    0.800000
# 50%    1713.500000    1.000000  18628.000000    0.0    1.0    1.400000
# 75%    2610.500000    1.000000  21200.500000    0.0    1.0    3.400000
# max    4795.000000    2.000000  28650.000000    0.0    1.0    7.300000
#
#           Albumin   Platelets  Prothrombin       Stage
# count  412.000000  412.000000   412.000000  412.000000
# mean     3.503701  255.561286    10.685599    3.024272
# std      0.412706   93.470600     0.843512    0.882042
# min      2.445000   62.000000     9.000000    1.000000
# 25%      3.247500  190.000000    10.000000    2.000000
# 50%      3.530000  249.000000    10.600000    3.000000
# 75%      3.782500  314.500000    11.100000    4.000000
# max      4.585000  501.250000    12.750000    4.000000

# %% [markdown]
# ### Normalize the data

# %%
def standardize_columns(df, columns_to_include):
    
    df_copy = df.copy() 
    
    for col in columns_to_include:
        if col in df_copy.columns:
            df_copy[col] = (df_copy[col] - df_copy[col].mean()) / df_copy[col].std()
    
    return df_copy

# %%
df = standardize_columns(df, ['N_Days', 'Age', 'Bilirubin', 'Albumin', 'Platelets', 'Prothrombin'])

# %%
df.describe()
# Out:
#              N_Days      Status           Age    Sex  Edema     Bilirubin  \
# count  4.120000e+02  412.000000  4.120000e+02  412.0  412.0  4.120000e+02
# mean   3.449237e-17    0.679612 -2.026426e-16    0.0    1.0  5.173855e-17
# std    1.000000e+00    0.583030  1.000000e+00    0.0    0.0  1.000000e+00
# min   -1.705398e+00    0.000000 -2.327660e+00    0.0    1.0 -9.539371e-01
# 25%   -7.478467e-01    0.000000 -7.555593e-01    0.0    1.0 -7.360031e-01
# 50%   -1.848621e-01    1.000000  3.392353e-02    0.0    1.0 -4.744824e-01
# 75%    6.306361e-01    1.000000  7.067002e-01    0.0    1.0  3.972534e-01
# max    2.616651e+00    2.000000  2.654941e+00    0.0    1.0  2.097138e+00
#
#             Albumin     Platelets   Prothrombin       Stage
# count  4.120000e+02  4.120000e+02  4.120000e+02  412.000000
# mean  -5.863702e-16 -9.485401e-17  8.278168e-16    3.024272
# std    1.000000e+00  1.000000e+00  1.000000e+00    0.882042
# min   -2.565266e+00 -2.070825e+00 -1.998310e+00    1.000000
# 25%   -6.207840e-01 -7.014108e-01 -8.127909e-01    2.000000
# 50%    6.372218e-02 -7.019626e-02 -1.014794e-01    3.000000
# 75%    6.755374e-01  6.305588e-01  4.912803e-01    4.000000
# max    2.620020e+00  2.628513e+00  2.447387e+00    4.000000

# %%
plot_boxplots_in_subplots(df)

# %% [markdown]
# ### OverSampling

# %%
smote = SMOTE()

X = df.drop('Stage', axis=1)
y = df['Stage']

# %%
# Apply SMOTE
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
# Convert back to DataFrame
df = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='Stage')], axis=1)

# %%
df.describe()
# Out:
#            N_Days      Status         Age    Sex  Edema   Bilirubin  \
# count  620.000000  620.000000  620.000000  620.0  620.0  620.000000
# mean     0.185852    0.739555   -0.068142    0.0    1.0   -0.155345
# std      0.989158    0.520346    0.926743    0.0    0.0    0.926353
# min     -1.705398    0.000000   -2.327660    0.0    1.0   -0.953937
# 25%     -0.563973    0.000000   -0.732418    0.0    1.0   -0.779590
# 50%      0.153338    1.000000   -0.047606    0.0    1.0   -0.605243
# 75%      0.848231    1.000000    0.533962    0.0    1.0    0.095068
# max      2.616651    2.000000    2.654941    0.0    1.0    2.097138
#
#           Albumin   Platelets  Prothrombin       Stage
# count  620.000000  620.000000   620.000000  620.000000
# mean     0.144212    0.081937    -0.108613    2.500000
# std      0.934551    0.920223     0.960128    1.118937
# min     -2.565266   -2.070825    -1.998310    1.000000
# 25%     -0.372423   -0.498138    -0.824447    1.750000
# 50%      0.233334    0.027591    -0.235337    2.500000
# 75%      0.790631    0.629286     0.372728    3.250000
# max      2.620020    2.628513     2.447387    4.000000

# %%
plot_boxplots_in_subplots(df)

# %% [markdown]
# ## Normalize and Handle Outliers again

# %%
df = handle_outliers(df)
df = standardize_columns(df, ['N_Days', 'Age', 'Bilirubin', 'Albumin', 'Platelets', 'Prothrombin'])

plot_boxplots_in_subplots(df)

# %%
plot_distributions_in_subplots(df)

# %% [markdown]
# ### Split Data

# %%
X = df.drop(columns=['Stage'])
y = df['Stage']

# %%
X.describe()
# Out:
#              N_Days      Status           Age    Sex  Edema     Bilirubin  \
# count  6.200000e+02  620.000000  6.200000e+02  620.0  620.0  6.200000e+02
# mean  -4.584147e-17    0.739555  1.719055e-17    0.0    1.0 -9.168293e-17
# std    1.000000e+00    0.520346  1.000000e+00    0.0    0.0  1.000000e+00
# min   -1.911980e+00    0.000000 -2.440954e+00    0.0    1.0 -9.485288e-01
# 25%   -7.580439e-01    0.000000 -7.172741e-01    0.0    1.0 -7.217267e-01
# 50%   -3.287026e-02    1.000000  2.267352e-02    0.0    1.0 -4.949245e-01
# 75%    6.696394e-01    1.000000  6.510652e-01    0.0    1.0  4.160850e-01
# max    2.457444e+00    2.000000  2.703574e+00    0.0    1.0  2.122802e+00
#
#             Albumin     Platelets   Prothrombin
# count  6.200000e+02  6.200000e+02  6.200000e+02
# mean   1.146037e-17 -4.440892e-17  2.292073e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.485392e+00 -2.360962e+00 -2.012823e+00
# 25%   -5.744147e-01 -6.330791e-01 -7.555914e-01
# 50%    8.911891e-02 -5.546935e-02 -1.246425e-01
# 75%    6.995699e-01  6.056023e-01  5.266077e-01
# max    2.610547e+00  2.463624e+00  2.449906e+00

# %%
y.describe()
# Out:
# count    620.000000
# mean       2.500000
# std        1.118937
# min        1.000000
# 25%        1.750000
# 50%        2.500000
# 75%        3.250000
# max        4.000000
# Name: Stage, dtype: float64

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (496, 9)

# %% [markdown]
# ## Implementation of Neural Network from Scratch

# %% [markdown]
# ###  1 Initialize Neural Network Architecture

# %%
hidden_size = 15

# %%
input_size = X_train.shape[1]
output_size = len(np.unique(y_train))

input_size, output_size
# Out:
# (9, 4)

# %%
input_to_hidden_w = np.random.randn(input_size, hidden_size) * 0.01
input_to_hidden_bias = np.zeros((1, hidden_size))

input_to_hidden_w.shape, input_to_hidden_bias.shape
# Out:
# ((9, 15), (1, 15))

# %%
hidden_to_output_w = np.random.randn(hidden_size, output_size) * 0.01
hidden_to_output_bias = np.zeros((1, output_size))

hidden_to_output_w.shape, hidden_to_output_bias.shape
# Out:
# ((15, 4), (1, 4))

# %% [markdown]
# ### 2. Forward Propagation

# %%
# softmax function - used for multiclass classification
def softmax(Z):
    exp_vals = np.exp(Z)
    probablities = exp_vals / np.sum(exp_vals, axis=1, keepdims=True)
    return probablities

# %%
def forward_propogation(X, weights_input_hidden, bias_input_hidden, weights_hidden_output, bias_hidden_output):
    
    # input to hidden layer
    Z_hidden = np.dot(X, weights_input_hidden) + bias_input_hidden
    activation_hidden = np.maximum(0, Z_hidden)

    # hidden to output layer
    Z_output = np.dot(activation_hidden, weights_hidden_output) + bias_hidden_output
    A_output = softmax(Z_output)

    return Z_hidden, activation_hidden, Z_output, A_output

# %%
# cross entropy loss
def calculate_loss(y_true, y_pred):

    # to avoid log(0) errors
    epsilon = 1e-15 
    y_pred = np.clip(y_pred, epsilon, 1 - epsilon)

    loss = -np.sum(y_true * np.log(y_pred)) / y_true.shape[0]

    return loss

# %% [markdown]
# ## 3. Backpropagation

# %% [markdown]
# ### Compute Gradients

# %%
def compute_output_layer_gradients(y_true, y_pred):

    # difference between predicted and true labels
    delta_output = y_pred - y_true
    
    return delta_output

# %%
def compute_hidden_layer_gradients(delta_output, weights_hidden_output, Z_hidden):

    # Backpropagate error to hidden layer
    delta_hidden = np.dot(delta_output, weights_hidden_output.T) * (Z_hidden > 0)
    
    return delta_hidden

# %%
def compute_weight_and_bias_gradients(X, delta_hidden, delta_output, activation_hidden):

    # Compute weight gradient for hidden-to-output layer
    grad_W_hidden_output = np.dot(activation_hidden.T, delta_output)
    grad_B_hidden_output = np.sum(delta_output, axis=0, keepdims=True)
    
    # Compute weight gradient for input-to-hidden layer
    grad_W_input_hidden = np.dot(X.T, delta_hidden)
    grad_B_input_hidden = np.sum(delta_hidden, axis=0, keepdims=True)
    
    return {
        "grad_W_hidden_output": grad_W_hidden_output,
        "grad_B_hidden_output": grad_B_hidden_output,
        "grad_W_input_hidden": grad_W_input_hidden,
        "grad_B_input_hidden": grad_B_input_hidden
    }

# %%
def backpropagation(X, y, activation_hidden, activation_output, weights_hidden_output, Z_hidden):
 
    # Compute output layer gradients
    delta_output = compute_output_layer_gradients(y, activation_output)
    
    # Compute hidden layer gradients
    delta_hidden = compute_hidden_layer_gradients(delta_output, weights_hidden_output, Z_hidden)
    
    # Compute weight gradients
    gradients = compute_weight_and_bias_gradients(X, delta_hidden, delta_output, activation_hidden)
    
    return gradients

# %% [markdown]
# ### Update Parameters

# %%
def update_parameters(weights_input_hidden, bias_input_hidden, weights_hidden_output, bias_hidden_output, gradients, learning_rate):

  # Update weights and biases for the hidden layer
  weights_input_hidden -= learning_rate * gradients["grad_W_input_hidden"]
  bias_input_hidden -= learning_rate * gradients["grad_B_input_hidden"]
  
  # Update weights and biases for the output layer
  weights_hidden_output -= learning_rate * gradients["grad_W_hidden_output"]
  bias_hidden_output -= learning_rate * gradients["grad_B_hidden_output"]
  
  return weights_input_hidden, bias_input_hidden, weights_hidden_output, bias_hidden_output

# %% [markdown]
# ## 4. Training Loop

# %%
# convert data
X_train = X_train.to_numpy()
X_test = X_test.to_numpy()

y_train = y_train.astype(int)
y_test = y_test.astype(int)

# %%
# apply one hot encoding
num_classes = len(np.unique(y_train))
y_train_one_hot = np.eye(num_classes)[y_train - 1]
y_test_one_hot = np.eye(num_classes)[y_test - 1]

# %%
# calcualte accuracy
def accuracy_score(y_true, y_pred):

    y_true_labels = np.argmax(y_true, axis=1)
    y_pred_labels = np.argmax(y_pred, axis=1)
    return np.mean(y_true_labels == y_pred_labels)

# %%
# hyperparameters
epochs = 5000
batch_size = 32
learning_rate = 0.0003

# %%
# get the number of samples
n_train = X_train.shape[0]
n_test = X_test.shape[0]

# %%
# store results for plotting
results = {
    "train_loss": [],
    "test_loss": [],
    "train_acc": [],
    "test_acc": [],
    "epoch":[]
}

# %%
# training loop
for epoch in range(1, epochs + 1):
    
    # Shuffle training data
    shuffle_indices = np.random.permutation(n_train)
    X_train_shuffled = X_train[shuffle_indices]
    y_train_shuffled = y_train_one_hot[shuffle_indices]

    # Mini-batch training
    for i in range(0, n_train, batch_size):
        X_batch = X_train_shuffled[i:i+batch_size]
        y_batch = y_train_shuffled[i:i+batch_size]

        # Forward pass using the forward_propogation function
        Z_hidden, activation_hidden, Z_output, activation_output = forward_propogation(
            X_batch,
            input_to_hidden_w, input_to_hidden_bias,
            hidden_to_output_w, hidden_to_output_bias
        )

        # Compute loss
        loss = calculate_loss(y_batch, activation_output)

        # Backpropogation
        gradients = backpropagation(
            X_batch, y_batch, 
            activation_hidden, activation_output,
            hidden_to_output_w, Z_hidden,
        )

        # Update parameters
        (input_to_hidden_w, input_to_hidden_bias, hidden_to_output_w, hidden_to_output_bias) = update_parameters(
             input_to_hidden_w, input_to_hidden_bias,
             hidden_to_output_w, hidden_to_output_bias,
             gradients, learning_rate
        )

    # Evaluate Training Set
    _, activation_hidden_train, _, activation_output_train = forward_propogation(
        X_train,
        input_to_hidden_w, input_to_hidden_bias,
        hidden_to_output_w, hidden_to_output_bias
    )

    train_loss = calculate_loss(y_train_one_hot, activation_output_train)
    train_acc = accuracy_score(y_train_one_hot, activation_output_train)

    # Evaluate Test Set
    _, activation_hidden_test, _, activation_output_test = forward_propogation(
        X_test,
        input_to_hidden_w, input_to_hidden_bias,
        hidden_to_output_w, hidden_to_output_bias
    )

    test_loss = calculate_loss(y_test_one_hot, activation_output_test)
    test_acc = accuracy_score(y_test_one_hot, activation_output_test)

    # Store results at every nth epoch
    if epoch % 250 == 0:
        results["train_loss"].append(train_loss)
        results["test_loss"].append(test_loss)
        results["train_acc"].append(train_acc)
        results["test_acc"].append(test_acc)
        results["epoch"].append(epoch)

        print(f"Epoch: {epoch}/{epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}")
# Out:
# Epoch: 250/5000, Train Loss: 1.1880, Train Acc: 0.4173, Test Loss: 1.1568, Test Acc: 0.4919
# Epoch: 500/5000, Train Loss: 1.1586, Train Acc: 0.4597, Test Loss: 1.1314, Test Acc: 0.5323
# Epoch: 750/5000, Train Loss: 1.1017, Train Acc: 0.4859, Test Loss: 1.0827, Test Acc: 0.5403
# Epoch: 1000/5000, Train Loss: 1.0594, Train Acc: 0.5363, Test Loss: 1.0563, Test Acc: 0.5565
# Epoch: 1250/5000, Train Loss: 1.0254, Train Acc: 0.5585, Test Loss: 1.0339, Test Acc: 0.5806
# Epoch: 1500/5000, Train Loss: 1.0031, Train Acc: 0.5605, Test Loss: 1.0261, Test Acc: 0.6129
# Epoch: 1750/5000, Train Loss: 0.9832, Train Acc: 0.5665, Test Loss: 1.0227, Test Acc: 0.6210
# Epoch: 2000/5000, Train Loss: 0.9647, Train Acc: 0.5746, Test Loss: 1.0115, Test Acc: 0.6048
# Epoch: 2250/5000, Train Loss: 0.9482, Train Acc: 0.5726, Test Loss: 1.0032, Test Acc: 0.5968
# Epoch: 2500/5000, Train Loss: 0.9329, Train Acc: 0.5867, Test Loss: 0.9946, Test Acc: 0.5968
# Epoch: 2750/5000, Train Loss: 0.9122, Train Acc: 0.6048, Test Loss: 0.9933, Test Acc: 0.5806
# Epoch: 3000/5000, Train Loss: 0.8889, Train Acc: 0.6290, Test Loss: 0.9849, Test Acc: 0.5887
# Epoch: 3250/5000, Train Loss: 0.8711, Train Acc: 0.6452, Test Loss: 0.9856, Test Acc: 0.6210
# Epoch: 3500/5000, Train Loss: 0.8569, Train Acc: 0.6371, Test Loss: 0.9769, Test Acc: 0.6290
# Epoch: 3750/5000, Train Loss: 0.8435, Train Acc: 0.6431, Test Loss: 0.9718, Test Acc: 0.6290
# Epoch: 4000/5000, Train Loss: 0.8341, Train Acc: 0.6573, Test Loss: 0.9676, Test Acc: 0.6452
# Epoch: 4250/5000, Train Loss: 0.8248, Train Acc: 0.6552, Test Loss: 0.9640, Test Acc: 0.6532
# Epoch: 4500/5000, Train Loss: 0.8161, Train Acc: 0.6673, Test Loss: 0.9624, Test Acc: 0.6613
# Epoch: 4750/5000, Train Loss: 0.8091, Train Acc: 0.6774, Test Loss: 0.9625, Test Acc: 0.6613
# Epoch: 5000/5000, Train Loss: 0.8028, Train Acc: 0.6774, Test Loss: 0.9642, Test Acc: 0.6613

# %%
plt.figure(figsize=(14, 6))

# Plot loss
plt.subplot(1, 2, 1)
plt.plot(results["epoch"], results["train_loss"], label='Train Loss')
plt.plot(results["epoch"], results["test_loss"], label='Test Loss')
plt.title("Train vs Test Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# Plot accuracy
plt.subplot(1, 2, 2)
plt.plot(results["epoch"], results["train_acc"], label='Train Accuracy')
plt.plot(results["epoch"], results["test_acc"], label='Test Accuracy')
plt.title("Train vs Test Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()
